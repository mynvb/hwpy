# %% [markdown]
# # Домашнее задание 3
# ## Сравнение интересов аудитории телеканалов НТВ и Дождь с помощью тематического моделирования LDA

# %% [markdown]
# Задача:
# Сравнить интересы аудитории телеканолов НТВ и Дождь с помощью методов тематического моделирования
# 1. Получить данные по аудитории из социальной сети ВК
# 2. Зарегистрировать приложение, получить app_id, access_token
# 3. Скачать данные по пользователям в каждой из групп (id групп ВК даны ниже, tvrain_id, ntv_id)
# 4. Взять небольшую выборку из каждой совокупности телезрителей(около 1000-2000 человек, т.к. 300k-400k слишком много), с которыми работать дальше
# 5. Обучить LDA модель на их подписках
# 6. По группам, на которые подписаны эти люди, полуичть ключевые слова групп, на которые они подписаны
# 7. Получить распределение интересов людей для каждой группы, сравнить на графике
#
# Дополнительно:
# - По любой группе пользователей построить матрицу Пользователь-Паблик, где 1 будет означать факт подписки на определенный паблик, 0 - отсутствие подписки (строки - пользователи, столбцы - паблики) и применить PCA - метод главных компонент, посмотреть, что из себя представляют топ-5 компонент и описать, какие интересы пользователей эти компоненты представляют

# %%
import seaborn as sb
import sys  
import pandas as pd
import requests
import numpy as np
import datetime
import time
import pickle
import matplotlib.pyplot as plt
import time
# %matplotlib inline

from bs4 import BeautifulSoup as bs
import urllib

# %%
def load_obj(name):
    with open(name + '.pkl', 'rb') as f:
        return pickle.load(f)

def save_obj(obj, name):
    with open(name + '.pkl', 'wb') as f:
        pickle.dump(obj, f, pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# #### Для использования VK API необходимо создать приложение в VK
#
# 1. Создать приложение по адресу https://vk.com/apps?act=manage (кнопка "создать приложение")
# 2. При создании указать название, описание (можно любые), категория  - прочее. Тип - standalone приложение
# 3. В настройках получить **app_id**. App_id потребуется для получения access token
# 4. Авторизовать пользователя (получить access token) можно по адресу: https://vk.com/dev/first_guide, в правилах нас интересует пункт 3 **Авторизация пользователя**
# 5. После того, как ознакомитесь с авторизацией пользователя, скопируйте в адресную строку такой запрос https://oauth.vk.com/authorize?client_id=5490057&display=page&redirect_uri=https://oauth.vk.com/blank.html&scope=friends&response_type=token&v=5.52, где число **5490057** замените на число, которое получите для вашего **app_id**
# 6. Нажмите Enter. Откроется окно с запросом прав. В нем отображаются название приложения, иконки прав доступа, и Ваши имя с фамилией. Нажмите «Разрешить». Вы попадете на новую страницу с предупреждением о том, что токен нельзя копировать и передавать третьим лицам. В адресной строке будет URL https://oauth.vk.com/blank.html, а после # Вы увидите дополнительные параметры — access_token, expires_in и user_id. Токен может выглядеть, например, так: 51eff86578a3bbbcb5c7043a122a69fd04dca057ac821dd7afd7c2d8e35b60172d45a26599c08034cc40a
# 7. Токен — это Ваш ключ доступа. При выполнении определенных условий человек, получивший Ваш токен, может нанести существенный ущерб Вашим данным и данным других людей. Поэтому очень важно не передавать свой токен третьим лицам
# 8. Поле expires_in содержит время жизни токена в секундах. 86400 секунд — это ровно сутки. Через сутки полученный токен перестанет действовать, для продолжения работы нужно будет получить новый по такому же алгоритму

# %%
# use your own app id and respective tokens

# скопируйте сюда ваши app_id и access_token, полученные по методу, описанному выше
app_id = 6932320
access_token = 'dcbe137149e3cc1c900bee6d6c5e39ca2061bf1c8fc0174c7c8e9bcda6e9422ac810cb84117290db4fa48'

# id групп ВК Дождя и НТВ
tvrain_id = 17568841
ntv_id = 28658784

# %%
# проверка работы API и авторизации пользователя. Если возникает ошибка, то, возможно, access token необходимо обновить
check_id = 2

# api call and test
def vk_get_response(method, parameters, token):
    url = 'https://api.vk.com/method/' + method + '?' + parameters + '&access_token=' + token
#     print url
    return(requests.get(url).json())

answer = vk_get_response(
    'users.get', 'user_ids={0}&v=4.9&lang=ru'.format(check_id), access_token
)['response']
print(answer[0]['first_name'], answer[0]['last_name'])
# Out:
# Александра Владимирова

# %% [markdown]
# ### Получение подписчиков телеканалов НТВ и Дождь в VK

# %% [markdown]
# Получим объекты, которые содержат всю информацию о подпиичиках соответствующих групп (указанных в domains) и сохраним их на диск. Получим в итоге два файла - **ntv_subs** и **tvrain_subs** в формате **.pkl** - питоновский формат хранения данных

# %%
domains = ['ntv', 'tvrain']


for group_domain in domains:
    offset = 0
    group_id = group_domain
    fields = """sex,bdate,city,country,home_town,lists,domain,has_mobile,
    contacts,connections,education,universities,followers_count,occupation,last_seen,relation"""
    first_sample = vk_get_response(
        'groups.getMembers', 'group_id={0}&offset={1}&fields={2}&v=4.9&lang=ru'.format(
            group_id, offset, fields
        ), token=access_token
    )

    community_count = first_sample['response']['count']

    community_members = []
    #параметр offset определяет, с какой тысячи берутся следующие 1000 элементов (так устроено api vk по состоянию на 12 апреля)
    for i in range(community_count // 1000 + 1):
        offset = i * 1000
        if offset == 4000: break
        try:
            answer = vk_get_response(
                'groups.getMembers', 'group_id={0}&offset={1}&fields={2}&v=4.9&lang=ru'.format(
                    group_id, offset, fields), token=access_token
            )
            print("Offset: ", offset)
        except:
            print("Offset: ", offset, " Error")
        community_members += answer['response']['users']
    save_obj(community_members, '{}_subs'.format(group_domain))
# Out:
# Offset:  0
# Offset:  1000
# Offset:  2000
# Offset:  3000
# Offset:  0
# Offset:  1000
# Offset:  2000
# Offset:  3000

# %%
community_ntv = load_obj('ntv_subs')
community_tvrain = load_obj('tvrain_subs')

# %%
community_ntv_df = pd.DataFrame(community_ntv)
community_tvrain_df = pd.DataFrame(community_tvrain)

# %% [markdown]
# Сначала получим всех уникальных подписчиков НТВ и Дождя с помощью unique. Далее с помощью numpy.random необходимо выбрать небольшой sample (например, по 1000 из каждой группы) таких людей и объединить их вместе

# %%
ntv_uids = community_ntv_df.uid.unique().tolist()
tvrain_uids = community_tvrain_df.uid.unique().tolist()

# %%
# получить общий список людей из двух выборок НТВ и Дождя, всего должно быть в итоге около 2000 человек
import random
uids = random.sample(ntv_uids+tvrain_uids, 2000)

# %%
# получить подписки этих пользователей
print_counter = 0
final_data = []

for uid in uids:
    try:
        user_subs = vk_get_response(
            'users.getSubscriptions', 'user_id={0}&v=4.9&lang=ru'.format(int(uid)), access_token)
        time.sleep(0.3)
        final_data.append(user_subs)
    except:
        print("Error")
    if print_counter % 100 == 0:
        print("{0} profiles done".format(print_counter))
    print_counter += 1
# Out:
# 0 profiles done
# 100 profiles done
# 200 profiles done
# 300 profiles done
# 400 profiles done
# 500 profiles done
# 600 profiles done
# 700 profiles done
# 800 profiles done
# 900 profiles done
# 1000 profiles done
# 1100 profiles done
# 1200 profiles done
# 1300 profiles done
# 1400 profiles done
# 1500 profiles done
# 1600 profiles done
# 1700 profiles done
# 1800 profiles done
# 1900 profiles done

# %%
import pprint
output = pprint.PrettyPrinter(indent=4)
output.pprint(final_data[1000])
# Out:
# {   'response': {   'groups': {   'count': 186,
#                                   'items': [   101360639,
#                                                170486851,
#                                                137793489,
#                                                26750264,
#                                                34598021,
#                                                23164653,
#                                                34486229,
#                                                26970810,
#                                                51080434,
#                                                36184135,
#                                                28220582,
#                                                38379853,
#                                                23958792,
#                                                40586683,
#                                                93384123,
#                                                45064245,
#                                                61904449,
#                                                127925490,
#                                                107019848,
#                                                107141800,
#                                                39410028,
#                                                36283224,
#                                                35059398,
#                                                30447908,
#                                                93958959,
#                                                69576154,
#                                                5880263,
#                                                34451036,
#                                                157775369,
#                                                34351491,
#                                                124142365,
#                                                46117626,
#                                                43207877,
#                                                91401869,
#                                                39728801,
#                                                35486195,
#                                                39108688,
#                                                29246653,
#                                                30953300,
#                                                149244472,
#                                                41095615,
#                                                35157161,
#                                                44222685,
#                                                58170807,
#                                                29698527,
#                                                46769525,
#                                                34086497,
#                                                35979047,
#                                                36008740,
#                                                60394803,
#                                                31805219,
#                                                32231484,
#                                                34964358,
#                                                69580110,
#                                                40335272,
#                                                135371955,
#                                                28528027,
#                                                34889014,
#                                                35113021,
#                                                119769385,
#                                                58916750,
#                                                23626598,
#                                                32922940,
#                                                34454611,
#                                                92581206,
#                                                11392978,
#                                                28950133,
#                                                25001884,
#                                                36812182,
#                                                38233726,
#                                                80410546,
#                                                30018563,
#                                                25153764,
#                                                29905631,
#                                                73267908,
#                                                162695262,
#                                                34483558,
#                                                41883468,
#                                                47029734,
#                                                251221,
#                                                24652430,
#                                                54030106,
#                                                34137285,
#                                                28627911,
#                                                33118494,
#                                                35171030,
#                                                39733006,
#                                                25189523,
#                                                25129453,
#                                                40020304,
#                                                5608669,
#                                                85620209,
#                                                1331201,
#                                                48512305,
#                                                65702001,
#                                                24471209,
#                                                383476,
#                                                689437,
#                                                4178714,
#                                                8782532,
#                                                14976455,
#                                                23228995,
#                                                23507788,
#                                                23616160,
#                                                23747816,
#                                                23770654,
#                                                23917344,
#                                                24226428,
#                                                24722253,
#                                                25783028,
#                                                27375897,
#                                                28527947,
#                                                28565318,
#                                                28658784,
#                                                29614963,
#                                                29695481,
#                                                29760133,
#                                                30179770,
#                                                30787858,
#                                                30975621,
#                                                31733986,
#                                                33066471,
#                                                33080201,
#                                                33390409,
#                                                33704958,
#                                                33842750,
#                                                34118551,
#                                                34168005,
#                                                34344752,
#                                                35114569,
#                                                35176356,
#                                                35683607,
#                                                35782117,
#                                                36672511,
#                                                36692222,
#                                                36959676,
#                                                37391221,
#                                                38363244,
#                                                38670067,
#                                                39321576,
#                                                39430634,
#                                                39673048,
#                                                39973713,
#                                                40167434,
#                                                41170309,
#                                                41226912,
#                                                41894607,
#                                                42082503,
#                                                42296923,
#                                                42301944,
#                                                42502560,
#                                                42790058,
#                                                43688579,
#                                                44881947,
#                                                45103558,
#                                                45244683,
#                                                45493806,
#                                                46603834,
#                                                46605295,
#                                                47118092,
#                                                48655987,
#                                                50246548,
#                                                51696572,
#                                                52851059,
#                                                52871233,
#                                                53680091,
#                                                54446892,
#                                                54757151,
#                                                57102670,
#                                                59840447,
#                                                63140506,
#                                                64857196,
#                                                68669088,
#                                                69757128,
#                                                71030460,
#                                                71849361,
#                                                84524513,
#                                                89776115,
#                                                91062325,
#                                                96657351,
#                                                103199839,
#                                                106042931,
#                                                108585218,
#                                                115329986,
#                                                120291623,
#                                                137932251]},
#                     'users': {   'count': 5,
#                                  'items': [   6093463,
#                                               165089010,
#                                               97578516,
#                                               213498816,
#                                               76588610]}}}

# %%
#собираем информацию о группах
subs_list = []
groups_freq_dict = {}
top_n = 5

for record, uid in zip(final_data, uids):
    try:
        user_subs = record
        if not user_subs.get('response'):
            user_subs = vk_get_response(
                'users.getSubscriptions', 'user_id={0}&v=4.9&lang=ru'.format(int(uid)), access_token
            )
        subs_pd = pd.DataFrame(
            [
                {
                    'groups_count': user_subs['response']['groups'].get('count'),
                    'groups_list': user_subs['response']['groups'].get('items'),
                    'follows_count':user_subs['response']['users'].get('count'),
                    'follows_list': user_subs['response']['users'].get('items'),
                }
            ]
        )
#считаем, насколько часто встречаются группы
        for group_id in user_subs['response']['groups'].get('items')[:top_n]:
            if groups_freq_dict.get(group_id):
                groups_freq_dict[group_id] += 1
            else:
                groups_freq_dict[group_id] = 1

        subs_pd['subs_count'] = subs_pd['groups_count'] + subs_pd['follows_count']
        subs_list.append(subs_pd)
    except:
#         print(user_subs)
        pass
    if len(subs_list) % 100 == 0:
        print("Processed {0} users".format(len(subs_list)))
# Out:
# Processed 0 users
# Processed 100 users
# Processed 200 users
# Processed 300 users
# Processed 300 users
# Processed 400 users
# Processed 500 users
# Processed 600 users
# Processed 600 users
# Processed 700 users
# Processed 800 users
# Processed 800 users
# Processed 900 users
# Processed 1000 users
# Processed 1100 users
# Processed 1200 users
# Processed 1300 users
# Processed 1300 users
# Processed 1400 users
# Processed 1400 users
# Processed 1400 users

# %%
subs_pd.head()
# Out:
#    follows_count                    follows_list  groups_count  \
# 0              3  [198888123, 144784833, 534700]            89
#
#                                          groups_list  subs_count
# 0  [180948769, 36338110, 137793489, 41438047, 420...          92

# %% [markdown]
# Самые популярные группы

# %%
sorted([(key, val) for key, val in groups_freq_dict.items()], key=lambda x: x[1], reverse=True)[:5]
# Out:
# [(17568841, 120),
#  (68471405, 95),
#  (28658784, 60),
#  (29534144, 57),
#  (63731512, 44)]

# %% [markdown]
# Загрузка постов со стен групп

# %%
group_doc_dict = {}
counter = 0
groups_freq_dict_top5 = groups_freq_dict

for group_id, freq in groups_freq_dict_top5.items():
    counter += 1
    try:
        check = vk_get_response(
            'wall.get',
            'owner_id={0}&count=15&&fields=post_type,marked_as_ads&v=4.9&lang=ru'.format(int(group_id) * -1),
            access_token
        )
        check = check['response']
        group_doc = ''
        if check[0] != 0:
            for post in check[1:]:
                if post.get('marked_as_ads') != 1:
                    group_doc += post['text']
        group_doc_dict[group_id] = group_doc

    except:
        print("Response error. Group id {0}".format(group_id))
        #print(check)
    if counter % 100 == 0:
        print("{0} groups extracted".format(counter))
    time.sleep(0.3)
# Out:
# 100 groups extracted
# 200 groups extracted
# 300 groups extracted
# 400 groups extracted
# 500 groups extracted
# 600 groups extracted
# Response error. Group id 108057937
# 700 groups extracted
# 800 groups extracted
# 900 groups extracted
# 1000 groups extracted
# 1100 groups extracted
# 1200 groups extracted
# 1300 groups extracted
# 1400 groups extracted
# 1500 groups extracted
# 1600 groups extracted
# 1700 groups extracted
# 1800 groups extracted
# 1900 groups extracted
# 2000 groups extracted
# 2100 groups extracted
# 2200 groups extracted
# 2300 groups extracted
# Response error. Group id 150817965
# 2400 groups extracted
# 2500 groups extracted
# 2600 groups extracted
# Response error. Group id 85873405
# Response error. Group id 176766899
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-33-84e852bc42f0> in <module>()
#      24     if counter % 100 == 0:
#      25         print("{0} groups extracted".format(counter))
# ---> 26     time.sleep(0.3)
#
# KeyboardInterrupt:

# %%
print(len(group_doc_dict))
# Out:
# 2664

# %%
# сохранить сырые данные по постам групп на диск
save_obj(group_doc_dict, 'group_doc_dict')

# %%
from bs4 import BeautifulSoup
import re
import string
from nltk import word_tokenize
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
import nltk
from pymorphy2 import MorphAnalyzer

# %%
chrs_to_delete = string.punctuation + u'»' + u'«' + u'—' + u'“' + u'„' + u'•' + u'#'
translation_table = {ord(c): None for c in chrs_to_delete if c != u'-'}
units = MorphAnalyzer.DEFAULT_UNITS
morph = MorphAnalyzer(result_type=None, units=units)
PortSt = PorterStemmer()
stopw = set(
    [w for w in stopwords.words('russian')]
    #[w for w in stopwords.words(['russian', 'english'])]
    + [u'это', u'году', u'года', u'также', u'етот',
       u'которые', u'который', u'которая', u'поэтому',
       u'весь', u'свой', u'мочь', u'eтот', u'например',
       u'какой-то', u'кто-то', u'самый', u'очень', u'несколько',
       u'источник', u'стать', u'время', u'пока', u'однако',
       u'около', u'немного', u'кроме', u'гораздо', u'каждый',
       u'первый', u'вполне', u'из-за', u'из-под',
       u'второй', u'нужно', u'нужный', u'просто', u'большой',
       u'хороший', u'хотеть', u'начать', u'должный', u'новый', u'день',
       u'метр', u'получить', u'далее', u'именно', u'апрель',
       u'сообщать', u'разный', u'говорить', u'делать',
       u'появиться', u'2016',
       u'2015', u'получить', u'иметь', u'составить', u'дать', u'читать',
       u'ничто', u'достаточно', u'использовать',
       u'принять', u'практически',
       u'находиться', u'месяц', u'достаточно', u'что-то', u'часто',
       u'хотеть', u'начаться', u'делать', u'событие', u'составлять',
       u'остаться', u'заявить', u'сделать', u'дело',
       u'примерно', u'попасть', u'хотя', u'лишь', u'первое',
       u'больший', u'решить', u'число', u'идти', u'давать', u'вопрос',
       u'сегодня', u'часть', u'высокий', u'главный', u'случай', u'место',
       u'конец', u'работать', u'работа', u'слово', u'важный', u'сказать']
)

# %%
url_start = 'http[s]?://'
url_end = (
    '(?:[a-zA-Z]|[0-9]|[$-_@.&+]|[!*\(\),]|(?:%[0-9a-fA-F][0-9a-fA-F]))+'
)
pattern = url_start + url_end

# %% [markdown]
# Обработка слов постов групп - трансформация в "хороший" вид. Нормализация и стэмминг, удаление стоп-слов

# %%
group_clean_doc_dict = {}
counter = 0

for group_id, doc in group_doc_dict.items():
    soup = BeautifulSoup(doc, 'html.parser')
    body = ' '.join(
        [tag.string.replace('\\n', ' ').replace('\\r', ' ')
         for tag in soup.descendants if tag.string]
    )
    body = re.sub('\[.*?\]','', body)
    body = re.sub(pattern,'', body)
    if body != '':
        body_clean = body.translate(translation_table).lower().strip()
        words = word_tokenize(body_clean)
        tokens = []
        # stemming and text normalization
        for word in words:
            if re.match('^[a-z0-9-]+$', word) is not None:
                tokens.append(PortSt.stem(word))
            elif word.count('-') > 1:
                tokens.append(word)
            else:
                normal_forms = morph.normal_forms(word)
                tokens.append(normal_forms[0] if normal_forms else word)
        # remove stopwords and leave unique words only
        tokens = filter(
            lambda token: token not in stopw, sorted(set(tokens))
        )

        # remove all words with more than 3 chars
        tokens = filter(lambda token: len(token) > 3, tokens)
    else:
        tokens = []
    counter += 1
    if counter % 100 == 0:
        print("{0} docs processed".format(counter))
    group_clean_doc_dict[group_id] = tokens

group_clean_doc_dict = {key: list(val) for key, val in group_clean_doc_dict.items()}
# Out:
# 100 docs processed
# 200 docs processed
# 300 docs processed
# 400 docs processed
# 500 docs processed
# 600 docs processed
# 700 docs processed
# 800 docs processed
# 900 docs processed
# 1000 docs processed
# 1100 docs processed
# 1200 docs processed
# 1300 docs processed
# 1400 docs processed
# 1500 docs processed
# 1600 docs processed
# 1700 docs processed
# 1800 docs processed
# 1900 docs processed
# 2000 docs processed
# 2100 docs processed
# 2200 docs processed
# 2300 docs processed
# 2400 docs processed
# 2500 docs processed
# 2600 docs processed

# %%
# сохранить обработанные данные на диск
save_obj(group_clean_doc_dict, 'group_doc_dict_clean')

# %% [markdown]
# ### Обучение LDA модели

# %%
from gensim.corpora import TextCorpus
from gensim.models.ldamulticore import LdaMulticore
from gensim.models.ldamodel import LdaModel

class ListTextCorpus(TextCorpus):

    def get_texts(self):
        for doc in self.input:
            yield doc
                
mycorp = ListTextCorpus(input=group_clean_doc_dict.values())
justlda = LdaModel(
    corpus=mycorp, num_topics=20, passes=12
)
# Out:
# paramiko missing, opening SSH/SCP/SFTP paths will be disabled.  `pip install paramiko` to suppress

# %%
print('LdaModel performance')
for i in range(20):
    terms = justlda.get_topic_terms(i)
    print(i, ' '.join(map(lambda x: mycorp.dictionary.get(x[0]), terms)))
# Out:
# LdaModel performance
# 0 рпродать thoma lada photograph барнс italia эротика лагерфельд познер septemb
# 1 человек группа рубль город россия ждать участие друг проект пройти
# 2 вайба зубодробительный микстейп 4000₽ канал винокуров башкирский зыбкий сейчас-то shift
# 3 природоохранный тaким измeнить чacтo третьяк пoмoжeт кaждoгo пoмoгaть лиcтие cмыcть
# 4 octob рекомендуетcть преданно south america rodrigo dear сечь notion юрлицо
# 5 ютубер monkey 1310 булка cotton reconstruct фаланга помолвка 300-500 августейший
# 6 вкус масло добавить вкусный минута соль продукт вода любой количество
# 7 killah ростов-на-дону acidlov антоха vol2 припев вейп дрипка шоурумаоплачивать бельевой
# 8 your альбом ссылка time английский стиль представить world style with
# 9 альбом сингл music трек релиз record sound audio soul boom
# 10 чтoб oчeнь ecть тoлькo кoгдa дeнь этoт будeт тaкий мeнить
# 11 world lost over death лейбл live down call itun control
# 12 кухня мебель холодильник комната квартира плита стиральный шкаф диван комнатный
# 13 кoшка дакота cраз вообщe нaпримeр микрофонный лимитер своeм eyelash адриатический
# 14 комплект торг чехол коробка iphon размер состояние 3500 зарядка продать
# 15 человек жизнь знать друг жить любить ребёнок найти смотреть думать
# 16 матч лига манчестер футбол чемпион игрок барселона реал ливерпуль тайм
# 17 servic salt harmoni twitch wine then memori тaкиe бывaть гребаный
# 18 большe твoь coast habe sich detail compil sole oкaзaлиcь мужчинa
# 19 ждaть видeo 😍вота поднебесный вмecтe пoзжe пeрeд благoдарить слoжный дeлать

# %%
dummy_dict = {key: 0 for key in range(20)}

group_topics_dict_20 = {
    group_id: dict(list(dummy_dict.items()) + justlda.get_document_topics(mycorp.dictionary.doc2bow(text)))
    for group_id, text in group_clean_doc_dict.items()
}
check_pd_20 = pd.DataFrame.from_dict(group_topics_dict_20, orient='index')
check_pd_20.head(10)
print("Group distribution by the most relevant topic")
pd.Series.round(check_pd_20.idxmax(axis=1).value_counts() * 1. / len(check_pd_20), 2)
# Out:
# Group distribution by the most relevant topic
# 1     0.47
# 15    0.36
# 6     0.05
# 0     0.03
# 8     0.01
# 12    0.01
# 10    0.01
# 9     0.01
# 11    0.01
# 14    0.01
# 16    0.01
# 7     0.00
# 2     0.00
# 18    0.00
# 17    0.00
# 3     0.00
# 5     0.00
# 4     0.00
# 13    0.00
# 19    0.00
# dtype: float64

# %%
# dump lda model to disk
justlda.save('ldamodel_20_topics')

# %%
print("The most typical groups for every topic")
for i in range(20):
    terms = justlda.get_topic_terms(i)
    print(i, ' '.join(map(lambda x: mycorp.dictionary.get(x[0]), terms)))
    typical_groups = check_pd_20[i].sort_values(ascending=False).index[:10]
    for g in typical_groups:
        group_info = vk_get_response(
            'groups.getById', 'group_ids={0}&v=4.9&lang=ru'.format(g), access_token
        )
        print(group_info['response'][0]['name'] + ' ' + 'http://vk.com/club' + str(g))
        time.sleep(0.3)
    print()
# Out:
# The most typical groups for every topic
# 0 рпродать thoma lada photograph барнс italia эротика лагерфельд познер septemb
# Дома не поймут http://vk.com/club49439086
# Журнал Эротика http://vk.com/club29694340
# Креативный дизайн http://vk.com/club43503694
# FASHION http://vk.com/club21138656
# Amazing GoPro http://vk.com/club67490365
# Прогулки сквозь века http://vk.com/club44986529
# Идеальная http://vk.com/club27260779
# RealWorld Tactical | Tony Sentmanat http://vk.com/club123105774
# Девчата http://vk.com/club158356637
# Дом Моды http://vk.com/club32767736
#
# 1 человек группа рубль город россия ждать участие друг проект пройти
# Отдел по трудоустройству и работе с выпускниками http://vk.com/club38323119
# Работа в СПБ http://vk.com/club64543946
# Курсы 1С и экзамены (1С:Учебный центр №1) http://vk.com/club63402641
# «Главстрой Санкт-Петербург»: строим главное! http://vk.com/club121453076
# Работа в Минске http://vk.com/club73857889
# Промоутеры Нижний Новгород | Работа http://vk.com/club56848276
# Вакансии для хороших людей (САНКТ-ПЕТЕРБУРГ) http://vk.com/club37234340
# Работа/Объявления- Петергоф/Ломоносов/Стрельна http://vk.com/club142621212
# ФГБУ "НМИЦ им. В.А. Алмазова" Минздрава России http://vk.com/club68657700
# ДТП Абинск http://vk.com/club107268408
#
# 2 вайба зубодробительный микстейп 4000₽ канал винокуров башкирский зыбкий сейчас-то shift
# Неформат http://vk.com/club63523476
# плёнка http://vk.com/club31112617
# Интересные штуки http://vk.com/club45613675
# МХК http://vk.com/club33414947
# Наталия Орейро | Natalia Oreiro http://vk.com/club104052041
# ВидеоТема™ http://vk.com/club72094158
# Маникюр | Ногти http://vk.com/club35762179
# WOT NgIII (Запарижский Козак) http://vk.com/club69808184
# ❤ ОБОЖАЮ ВЯЗАТЬ ❤ http://vk.com/club120123815
# Фотобудка Самара RAZUBKO http://vk.com/club86847038
#
# 3 природоохранный тaким измeнить чacтo третьяк пoмoжeт кaждoгo пoмoгaть лиcтие cмыcть
# Самое интересное | Бот http://vk.com/club11787
# Гуру путешествий|Туризм|Путешествия|Отдых|Туры http://vk.com/club25682112
# Своими Руками | Так Просто http://vk.com/club149499405
# МадамНеВам http://vk.com/club117601161
# Игра Престолов http://vk.com/club19328401
# Cinemaholics http://vk.com/club35595350
# Типичная Лена Попова http://vk.com/club43652472
# ◄Фильмы► /HD≈1080p/ http://vk.com/club144798218
# Хвастайся, Волгоград http://vk.com/club135869004
# Бумажный самолётик http://vk.com/club52537634
#
# 4 octob рекомендуетcть преданно south america rodrigo dear сечь notion юрлицо
# Чёрно-белая фотография http://vk.com/club29937606
# Bass Toxic Team | АВТОЗВУК | http://vk.com/club164960540
# LUXURIOUS LIFE ™ http://vk.com/club39748345
# Rinat SH http://vk.com/club181039263
# Жизнь в Осло. Oslo http://vk.com/club172381382
# Популярная музыка http://vk.com/club35983383
# Бот Повар http://vk.com/club142655676
# Я тебя хочу http://vk.com/club43776215
# TESTFM http://vk.com/club89948776
# Фразы на испанском http://vk.com/club29257408
#
# 5 ютубер monkey 1310 булка cotton reconstruct фаланга помолвка 300-500 августейший
# MEN'S LOOKS http://vk.com/club34668842
# Traveller http://vk.com/club23964485
# Sеху Geek Girls Photos http://vk.com/club43234662
# VYLGARIS http://vk.com/club144270111
# Культовые диски из Европы http://vk.com/club37222610
# НОГТИWOOD http://vk.com/club157791518
# ЮТАЧ | ВЕСНА http://vk.com/club133777217
# ÖMANKÖ http://vk.com/club84648738
# Фотограф Москва //Kanpeki Y. Kan (Laita) http://vk.com/club38438128
# Я хочу... http://vk.com/club36008740
#
# 6 вкус масло добавить вкусный минута соль продукт вода любой количество
# ВПРОК http://vk.com/club50152225
# Высокая Кухня http://vk.com/club46491880
# Идеи для дома 🍓 http://vk.com/club55363991
# Диетические рецепты http://vk.com/club34889014
# ЖЕНСКИЙ ДОМ! http://vk.com/club52361900
# Комнатные растения | Домашние цветы http://vk.com/club83484414
# Женские секреты | Красное сухое http://vk.com/club175146460
# Фитнес Рецепты — правильное и здоровое питание http://vk.com/club80410546
# GIF рецепты http://vk.com/club70305484
# МЯСО | Мужская кухня http://vk.com/club68988957
#
# 7 killah ростов-на-дону acidlov антоха vol2 припев вейп дрипка шоурумаоплачивать бельевой
# Перекати-тело http://vk.com/club72072815
# Невада http://vk.com/club34458451
# PRO FRONT | автозвук | http://vk.com/club105475621
# Убейся Позитивом 😅 http://vk.com/club24299135
# Дизайн интерьера http://vk.com/club33301261
# Искусство реальности http://vk.com/club26307864
# Мужской рай http://vk.com/club38290762
# Discovery http://vk.com/club25117353
# Ходячие Мертвецы | Сериалы http://vk.com/club14719576
# ➨VAPE ➨ВЕЙП БАРАХОЛКА ➨САНКТ–ПЕТЕРБУРГ ➨РОССИЯ http://vk.com/club11294576
#
# 8 your альбом ссылка time английский стиль представить world style with
# Hyper Illiterate http://vk.com/club158510728
# NEW MUSIC VIDEOS http://vk.com/club13895667
# JAPANISM http://vk.com/club54132631
# Уроки ПДД | Правила дорожного движения http://vk.com/club37660077
# Factura — арт http://vk.com/club25817269
# TATTOOSHKA ⚡ ТАТУИРОВКИ http://vk.com/club102208868
# Библиотека эскизов для татуировок http://vk.com/club107574265
# Жесть, какая татуировка! http://vk.com/club16348810
# MINT store http://vk.com/club37174112
# mopho | моментальная фотография http://vk.com/club170146354
#
# 9 альбом сингл music трек релиз record sound audio soul boom
# Drum and Bass | DnB http://vk.com/club27437985
# 9GAG http://vk.com/club32041317
# Juicy M http://vk.com/club54724719
# Студентки | Школьницы (18+) http://vk.com/club132834409
# kick a dope verse! http://vk.com/club94846016
# Родной звук http://vk.com/club83415396
# Пикачу-сальса http://vk.com/club124467333
# МХК http://vk.com/club41437811
# Поездато | Поезд каждый час http://vk.com/club153545654
# Непаблик 18+ http://vk.com/club72831913
#
# 10 чтoб oчeнь ecть тoлькo кoгдa дeнь этoт будeт тaкий мeнить
# HD Кино - Фильмы онлайн 2019 http://vk.com/club123915905
# [В] ГАРАЖЕ | Автомобильный журнал http://vk.com/club96389677
# Музыка для Спорта http://vk.com/club38480891
# Betraveler | Добро пожаловать на Землю http://vk.com/club26127512
# CONCEPT ART http://vk.com/club11203119
# Современная леди http://vk.com/club62076597
# Словарный запас |Психология| Amazings of History http://vk.com/club68573479
# Современное искусство http://vk.com/club35486596
# Простые Хитрости http://vk.com/club168789128
# Мой дом. Санкт-Петербург http://vk.com/club127925061
#
# 11 world lost over death лейбл live down call itun control
# Гений креатива http://vk.com/club45770903
# Идеи для дома - Дизайн интерьера http://vk.com/club49290489
# Русские Музыкальные Новинки 2019 http://vk.com/club31317869
# Дыши музыкой! http://vk.com/club17297
# Лепра http://vk.com/club30022666
# Всё для рыбалки / AliExpress http://vk.com/club167897570
# кусочек фильма http://vk.com/club70493648
# Suits / Форс-Мажоры http://vk.com/club14392583
# бюьюбюьб http://vk.com/club42276708
# Мемуары 107-миллиардного http://vk.com/club135968222
#
# 12 кухня мебель холодильник комната квартира плита стиральный шкаф диван комнатный
# SWEET HOME | Аренда жилья в Санкт-Петербурге http://vk.com/club159655174
# Аренда квартир и комнат без агентов СПб http://vk.com/club160909083
# Путешествия http://vk.com/club38363244
# Посуточная аренда квартир  в Санкт-Петербурге. http://vk.com/club150872114
# Ochra http://vk.com/club177988663
# Мировой Футбол http://vk.com/club4290276
# Пустота http://vk.com/club36683153
# Интеллектуальный юмор http://vk.com/club28950133
# MuaPh - ВИЗАЖИСТЫ и ФОТОГРАФЫ МИРА http://vk.com/club40686249
# Дизайн Интерьера | 33 кв. метра http://vk.com/club153272708
#
# 13 кoшка дакота cраз вообщe нaпримeр микрофонный лимитер своeм eyelash адриатический
# EA7 http://vk.com/club26492122
# Сладкая карамель http://vk.com/club132473659
# Безумный юмор http://vk.com/club37866176
# Без кота и жизнь не та ツ http://vk.com/club32015300
# Паёк купить продать Гаджиево Снежногорск Полярны http://vk.com/club118031375
# Vine Video http://vk.com/club57876954
# Hairurg | Тюмень http://vk.com/club175460060
# Женские Хитрости | Лайфхакерша http://vk.com/club23245066
# Племенной питомник  "ПИТ ПРАЙТ" порода Прайтер http://vk.com/club76266549
# Мир Дизайна http://vk.com/club49592543
#
# 14 комплект торг чехол коробка iphon размер состояние 3500 зарядка продать
# Карандаша Душа http://vk.com/club50670410
# Объявления Челябинск Барахолка (куплю продам)174 http://vk.com/club109161727
# Острые Козырьки http://vk.com/club26635295
# Perception of music http://vk.com/club35193970
# Мужские мысли http://vk.com/club25397178
# LIFESTYLE'R http://vk.com/club26599838
# Депутат Слуцкий наказан? http://vk.com/club163976737
# Милые вещи c AliExpress http://vk.com/club131500982
# Vintage Goods http://vk.com/club34993854
# Злой Гений http://vk.com/club39153701
#
# 15 человек жизнь знать друг жить любить ребёнок найти смотреть думать
# Протоиерей АРТЕМИЙ ВЛАДИМИРОВ(сообщество друзей) http://vk.com/club38489461
# Грустные стихи |Музыка|До слез http://vk.com/club35850885
# Доброе слово •Православие• http://vk.com/club33964345
# Kerob.TV - Перевод и озвучивание сериалов http://vk.com/club180326594
# Подслушали у замужних http://vk.com/club148881515
# Папа Франциск. Слово каждый день. http://vk.com/club50991269
# Империя Кино | Фильмы онлайн 2019 http://vk.com/club48319873
# Блаженная Матрона Московская http://vk.com/club29342594
# Православие http://vk.com/club23030430
# Мир мужчины и женщины http://vk.com/club60726980
#
# 16 матч лига манчестер футбол чемпион игрок барселона реал ливерпуль тайм
# Esthétique Europe: France | Italia http://vk.com/club130201306
# Убойный юмор http://vk.com/club30179569
# Четкие Приколы http://vk.com/club23064236
# ПИЗДАСТАЛИНА http://vk.com/club36295085
# Hairdorables http://vk.com/club169458757
# Тихие Радости Зла http://vk.com/club41811107
# Футбол Европы http://vk.com/club23693281
# Мир красоты http://vk.com/club34981365
# Little Design http://vk.com/club59046062
# Утро России http://vk.com/club77125248
#
# 17 servic salt harmoni twitch wine then memori тaкиe бывaть гребаный
# Как это переводится, Чувак? http://vk.com/club30598666
# Анекдотчик http://vk.com/club90598123
# Architecture For Life/ Архитектура/ Дизайн http://vk.com/club44728082
# Дедукция http://vk.com/club139215920
# ARCHVIS http://vk.com/club111328376
# Смех и Грех http://vk.com/club114112776
# Just Design - интерьер и декор http://vk.com/club42358972
# Типичный Сисадмин http://vk.com/club39243732
# Vape Russia | Доставка по России |  SPB Shop http://vk.com/club157549072
# AvtoJAPAN «Mercedes Benz㉦» Мытищи http://vk.com/club123716063
#
# 18 большe твoь coast habe sich detail compil sole oкaзaлиcь мужчинa
# la décadence http://vk.com/club108019374
# MirFactov - все самое интересное! http://vk.com/club22741084
# Красивый арт и косплей| art, cosplay, modeling http://vk.com/club60373985
# МИР РЕМНИ И ЧАСЫ http://vk.com/club177513535
# Фабрика идей http://vk.com/club43772432
# МОНТАЖ GIF http://vk.com/club158182528
# Психология личности http://vk.com/club70841494
# Открытки http://vk.com/club28890647
# Flaty http://vk.com/club88989969
# Telegram Stickers - Стикеры http://vk.com/club97263880
#
# 19 ждaть видeo 😍вота поднебесный вмecтe пoзжe пeрeд благoдарить слoжный дeлать
# Обитель Соблазна | Эротика | Ню 18+ http://vk.com/club86743996
# Кривые Руки http://vk.com/club165935205
# Аренда строительной техники http://vk.com/club177843424
# 1000 Идей маникюра | Дизайн ногтей http://vk.com/club119311457
# C h o p - C h o p http://vk.com/club39444069
# Style and Decor http://vk.com/club42689002
# ПОЗИТИВ ツ http://vk.com/club11614
# ГИФАЧ | ГИФКИ | GIF http://vk.com/club133643613
# Лепка из пластилина | Plast.me http://vk.com/club22447690
# Вот это смешно :D http://vk.com/club147166906
